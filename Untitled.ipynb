# %%
test_list = ['sarita', 67, 78.098, True, [5,6], (6,5), {"name":"sarita"}]
print(test_list)
# Out:
# ['sarita', 67, 78.098, True, [5, 6], (6, 5), {'name': 'sarita'}]

# %%
test_list[5] = 6
print(test_list)
# Out:
# ['sarita', 67, 78.098, True, [5, 6], 6, {'name': 'sarita'}]

# %%
test_list[5] = (6,5,5)
print(test_list)
# Out:
# ['sarita', 67, 78.098, True, [5, 6], (6, 5, 5), {'name': 'sarita'}]

# %%
test_list[5][0] = 8
print(test_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test_list[5][0] = 8
#       2 print(test_list)
#
# TypeError: 'tuple' object does not support item assignment
