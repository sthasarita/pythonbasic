# %%
#( #single line comment )
# for multiline comment we use """ """ , actually this is called docstring and there is no multiline comment available in python
# data type

# %%
x = 5
y = "5"
a = True
b = 5.5

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
type(a)
# Out:
# bool

# %%
type(b)
# Out:
# float

# %%
age = input("Enter the age:")
# Out:
# Enter the age: 12

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age = int(input("Enter your age:"))
print(age)
# Out:
# Enter your age: 12
# 12

# %%
name = "Sarita"
surname = "Shrestha"
age = 20

# %%
#fstring 
print(f"My name is {name} and surname is {surname}")
# Out:
# My name is Sarita and surname is Shrestha

# %%
#formatted string 
print("My name is {} {}".format(name,surname))
# Out:
# My name is Sarita Shrestha

# %%
#checking triple quote
a = """this is 
checking 
the triple quote string"""
print(a)
b = '''Hi hello how are
you'''
print(b)
c ="hi\nhello"
print(c)
# Out:
# this is
# checking
# the triple quote string
# Hi hello how are
# you
# hi
# hello

# %%
a= 5
print(type(a))
type(a)
# Out:
# <class 'int'>
# int

# %%
x = 5 
y = "5"
z = 5.5
a = True

# %%
b = str(x)
type(b+y)
# Out:
# str

# %%
z = x +y 
print(z)
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 z = x +y
#       2 print(z)
#       3 print(type(z))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a=5 
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>
