# %% [markdown]
# #### Session Objectives:
# *   Understand the motivation behind Object-Oriented Programming.
# *   Learn the core concepts: Classes, Objects, Attributes, and Methods.
# *   Learn how to define a simple class in Python.
# *   Understand the purpose and usage of the `__init__` constructor method.
# *   Learn how to create instances (objects) of a class.
# *   Learn how to access object attributes and call object methods.

# %% [markdown]
# # Why OOP?
#
#   **Analogy:** Think about building a house.
#   *   You start with a **blueprint** (the plan). This blueprint defines what a house *is* – it has walls, rooms, doors, windows, etc., and it specifies how these parts are related.
#   *   Using the blueprint, you can build multiple **actual houses**. Each house is a specific instance built *from* the blueprint. Each house has its own specific characteristics (e.g., one house might be painted blue, another red; one might have 3 bedrooms, another 4).

# %% [markdown]
# # Core OOP Concepts
#
# ## 1.  **Class:**
#      *   **Concept:** A blueprint or template for creating objects. It defines the properties and behaviors that all objects of that type will share.
#      *   **Analogy:** The house blueprint. It defines that a house *will have* walls, doors, rooms, etc.
#      *   **Python:** Defined using the 'class' keyword.
#
#
# ## 2.  **Object (Instance):**
#     *   **Concept:** A specific instance created from a class. It has its own unique state (values for its properties).
#     *   **Analogy:** An actual house built from the blueprint. It has a specific color, address, number of rooms.
#     *   **Python:** Created by "calling" the class name like a function (e.g., `my_house = House()`).
#
#
# ## 3.  **Attribute:**
#      *   **Concept:** Data associated with an object. Represents the state or characteristics of an object.
#      *   **Analogy:** Properties of a specific house, like its color (`"blue"`), number of stories (`2`), address (`"123 Main St"`).
#      *   **Python:** Variables that belong to an object (e.g., `my_house.color`). Often initialized in the `__init__` method.
#
# ## 4.  **Method:**
#      *   **Concept:** Functions associated with an object. Represents the behaviors or actions an object can perform. Methods often operate on the object's attributes.
#      *   **Analogy:** Actions a house (or things in it) can do, like `open_door()`, `turn_on_lights()`, `calculate_area()`.
#      *   **Python:** Functions defined inside a class. They always take `self` as their first parameter. (e.g., `my_house.open_door()`).

# %%
#Define a blueprint for a Dog
class Dog:
    pass
#creating objects
dog1 = Dog()
dog2 = Dog()
type(dog1)
print(type(dog2))
# Out:
# <class '__main__.Dog'>

# %%
#id is used to find the address of the object or variable and finding out whether the two object share same address or not
print(id(dog1)) 
print(id(dog2))
if dog1 is dog2:
    print("they have same address.")
else:
    print("They do not have same address.")
# Out:
# 3123610146128
# 3123608320144
# They do not have same address.

# %%
#the two objects are not same

print(dog1 == dog2)
# Out:
# False

# %%
class Dog:
    def __init__(self, name, breed, age):
        self.name = name 
        self.breed = breed
        self.age = age
        print(f"A new dog object name {self.name} was created!")

# %%
dog1 = Dog("jimmy","golden retriever", 2)
dog2 = Dog("Lucy", "German Shepherd", 6)
# Out:
# A new dog object name jimmy was created!
# A new dog object name Lucy was created!

# %%
#we don't use () to access the attribute

print(dog1.breed)
print(dog1.age)
dog1.name
# Out:
# golden retriever
# 2
# 'jimmy'

# %%
# Accessing Attributes
# We use the dot (`.`)

# `object_name.attribute_name`


print(f"Dog 1's Name: {dog1.name}")
print(f"Dog 1's Breed: {dog1.breed}")
print(f"Dog 1's Age: {dog1.age}")


print(f"\nDog 2's Name: {dog2.name}")
print(f"Dog 2's Breed: {dog2.breed}")
print(f"Dog 2's Age: {dog2.age}")

print(f"\nIs dog1's name the same as dog2's name? {dog1.name == dog2.name}")
# Out:
# Dog 1's Name: jimmy
# Dog 1's Breed: golden retriever
# Dog 1's Age: 2
#
# Dog 2's Name: Lucy
# Dog 2's Breed: German Shepherd
# Dog 2's Age: 6
#
# Is dog1's name the same as dog2's name? False

# %%
### Defining Methods

# Methods are functions defined inside a class that define the object's behavior. They also take `self` as the first parameter,
# allowing them to access and modify the object's attributes.


class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
       
        print(f"A new Dog object named {self.name} was created!")

    def bark(self):
        print(f"{self.name} says: Woof! Woof!")

    def describe(self):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed}.")


    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

    def __str__(self):
        return f"This is {self.name}"

# %%
### Calling Methods

# We use the dot (`.`) notation to call methods on a specific object.

# `object_name.method_name()`

# Create new dog objects using the updated class definition
dog1 = Dog("Buddy", "Golden Retriever", 3)
dog2 = Dog("Lucy", "Poodle", 5)
# Out:
# A new Dog object named Buddy was created!
# A new Dog object named Lucy was created!

# %%
print(dog1)
dog1.bark()
dog1.describe()
dog1.have_birthday()
print("\n--- Dog 1 Actions ---")
dog1.describe()
dog1.bark()
dog1.have_birthday()

# Call methods on dog2
print("\n--- Dog 2 Actions ---")
dog2.describe()
dog2.bark()

print(f"Dog 2's age is still: {dog2.age}")
# Out:
# This is Buddy
# Buddy says: Woof! Woof!
# This is Buddy, a 3-year-old Golden Retriever.
# Happy Birthday, Buddy! You are now 4 years old.
#
# --- Dog 1 Actions ---
# This is Buddy, a 4-year-old Golden Retriever.
# Buddy says: Woof! Woof!
# Happy Birthday, Buddy! You are now 5 years old.
#
# --- Dog 2 Actions ---
# This is Lucy, a 5-year-old Poodle.
# Lucy says: Woof! Woof!
# Dog 2's age is still: 5

# %%
#made by ourself  where we have used the color attribute which has not been included in the constructor
class Dog_class:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age
       
        print(f"A new Dog object named {self.name} was created!")

    def bark(self):
        print(f"{self.name} says: Woof! Woof!")

    def describe(self,color):
        print(f"This is {self.name}, a {self.age}-year-old {self.breed} with color {color}.")


    def have_birthday(self):
        self.age += 1
        print(f"Happy Birthday, {self.name}! You are now {self.age} years old.")

    def __str__(self):
        return f"This is {self.name}"

# %%
dog3 = Dog_class("Jack","German Shepherd", 3)
dog3.describe("red")
# Out:
# A new Dog object named Jack was created!
# This is Jack, a 3-year-old German Shepherd with color red.

# %%
# **Activity: Create a `Student` Class**

# Your task is to:
# 1.  Define a class named `Student`.
# 2.  Implement the `__init__` method. It should take `name` and `age` as arguments and store them as attributes `self.name` and `self.age`.
# 3.  Add a method named `introduce()` that prints a message like: "Hi, my name is [Name] and I am [Age] years old."
# 4.  Create at least two different `Student` objects with different names and ages.
# 5.  Call the `introduce()` method on each of your student objects.
# 6.  Use naming representation of objects

# %%
# Assignment
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")
    def __str__(self):
        return f"This is {self.name}"

student1 = Student("Saru", 20)
student2 = Student("Rita", 12)

print(student1)
print(student2)
# calling introduce() method on each object
student1.introduce()
student2.introduce()
# Out:
# This is Saru
# This is Rita
# Hi, my name is Saru and I am 20 years old.
# Hi, my name is Rita and I am 12 years old.

# %% [markdown]
# #Inheritance
#
# # ### Session Objectives:
# # *   Understand the concept of Inheritance and its benefits (code reuse, modeling relationships).
# # *   Learn how to define subclasses that inherit from superclasses in Python.
# # *   Understand and implement Method Overriding.
# # *   Learn how to use the `super()` function to call methods from the parent class.

# %%
# Defining Superclass and Subclass

class Person:
   
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print(f"object created: {self.name}")

    def introduce(self):
        print(f"Hi, my name is {self.name} and I am {self.age} years old.")

    def walk(self):
        print(f"{self.name} is walking in road.")

    

p1 = Person("Alice", 30)
p1.introduce()
p1.walk()
# Out:
# object created: Alice
# Hi, my name is Alice and I am 30 years old.
# Alice is walking in road.

# %%
#we can change the name as well as age of the object
p1.name = "Sarita"
p1.name
p1.age = 12
p1.age
# Out:
# 'Sarita'

# %%
# **Syntax:** `class ChildClassName(ParentClassName):`
#child class automatically gets the constructor written in the parent class and all the mehods as well as attributes of the parent class
#at first child class always looks at itself for constructor, attribute and methods
class Student(Person):
   
    pass

# Create a s1 object from student class
s1 = Student("Bob", 20)
# Out:
# object created: Bob

# %%
# Access attributes and methods defined in Person
print(f"Student's Name: {s1.name}")
s1.introduce()
s1.walk()

# Check the type and relationship
print(f"\nType of s1: {type(s1)}")
print(f"Is s1 an instance of Student? {isinstance(s1, Student)}")
print(f"Is s1 an instance of Person? {isinstance(s1, Person)}")
#S1 is the instance of both parent as well as child class Student
# Out:
# Student's Name: Bob
# Hi, my name is Bob and I am 20 years old.
# Bob is walking.
#
# Type of s1: <class '__main__.Student'>
# Is s1 an instance of Student? True
# Is s1 an instance of Person? True

# %%
# Adding Specific Attributes/Methods to Subclass


class Student(Person):
    def __init__(self, name, age, student_id, major):      
        super().__init__(name, age)
        self.student_id = student_id
        self.major = major
        print(f"student_id = {self.student_id}")

    def introduce(self):
        super().introduce()
        print(f" (ID: {self.student_id}) is studying {self.major}.")
       
    def study(self):
        print(f"{self.name} (ID: {self.student_id}) is studying {self.major}.")

        

s2 = Student("Charlie", 21, "S12345", "Computer Science")
# Out:
# object created: Charlie
# student_id = S12345

# %%
# Access inherited attributes/methods
print(f"Name: {s2.name}, Age: {s2.age}")
s2.walk()

# Access new attributes/methods
print(f"Student ID: {s2.student_id}, Major: {s2.major}")
s2.study()
# Out:
# Name: Charlie, Age: 21
# Charlie is walking.
# Student ID: S12345, Major: Computer Science
# Charlie (ID: S12345) is studying Computer Science.

# %%
s2.introduce()
# Out:
# Hi, my name is Charlie and I am 21 years old.
#  (ID: S12345) is studying Computer Science.

# %%
# ### Method Overriding
# Sometimes, a subclass needs to provide a specific implementation of a method that is already defined in its superclass.
# This is called **method overriding**.
# Example: The `introduce` method in `Person` is generic. A `Student` might want a more specific introduction.


class Student(Person): # Inherits from Person
    def __init__(self, name, age, student_id, major):
        super().__init__(name, age)
        self.student_id = student_id
        self.major = major
       

    def study(self):
        print(f"{self.name} (ID: {self.student_id}) is studying {self.major}.")

          
    def introduce(self):
        super().introduce()
        print(f"I am a student majoring in {self.major} with ID {self.student_id}.")
        
    def courses(self,course_lists):
        print(f"{self.name} has selected courses:")
        for course in course_lists:
            print(course)

p2 = Person("David", 45)
s3 = Student("Eve", 19, "S67890", "Computer Science")

print("\n--- Introductions ---")
p2.introduce()

print("-" * 10)
#here introduce() method of the child class runs at first and inside child class super() function runs which calls the parent class introduce function so it gets executed at first and then again the program control comes back to the child class introduce function
s3.introduce()
s3.courses(['AI','OS'])
# Out:
# object created: David
# object created: Eve
#
# --- Introductions ---
# Hi, my name is David and I am 45 years old.
# ----------
# Hi, my name is Eve and I am 19 years old.
# I am a student majoring in Computer Science with ID S67890.
# Eve has selected courses:
# AI
# OS

# %% [raw]
# Activities:
# Part 1: Base Class – Vehicle
# Attributes: brand, year
#
# Method:
# info() → prints: "This is a <brand> made in <year>."
#
# Part 2: Derived Class – Car(Vehicle)
# Extra attributes: model, seats
#
# Use super().__init__(brand, year)
#
# Method:
# drive() → prints: "Driving a <brand> <model> with <seats> seats."
#
# Part 3: Derived Class – Truck(Vehicle)
# Extra attributes: capacity_tons, wheels
#
# Use super().__init__(brand, year)
#
# Method:
# haul() → prints: "The <brand> truck is hauling <capacity_tons> tons with <wheels> wheels."

# %%
#answer
class Vehicle():
    def __init__(self,brand, year):
        self.brand = brand
        self.year = year
    def info(self):
        print(f"This is a {self.brand} made in {self.year}")
class Car(Vehicle):
    def __init__(self, brand, year,model,seats):
        super().__init__(brand, year)
        self.model = model
        self.seats = seats
    def drive(self):
        print(f"Driving a {self.brand} {self.model} with {self.seats} seats.")
        
class Truck(Vehicle):
    def __init__(self, brand, year,capacity_tons,wheels):
        super().__init__(brand, year)
        self.capacity_tons = capacity_tons
        self.wheels = wheels
    def haul(self):
        print(f"The {self.brand} truck is hauling {self.capacity_tons} tons with {self.wheels} wheels.")

c1= Car("Toyota", 2012, "Yarris", 5)

c1.info()
c1.drive()

t1 = Truck("Mahendra", 2011, 3, 4)
t1.info()
t1.haul()
# Out:
# This is a Toyota made in 2012
# Driving a Toyota Yarris with 5 seats.
# This is a Mahendra made in 2011
# The Mahendra truck is hauling 3 tons with 4 wheels.

# %% [markdown]
# #### Abstraction means:
# * Hiding complicated stuff (like wires inside the controller).
# * Showing only what’s important (the buttons you need to press).

# %%
# Abstraction is simply providing a common interface and hiding its implementation as in the program all abstract method has hide its details and  provide a interface of a method. 
# In python, for implementing abstraction ABC base class  and abstractmethod decorator is used. The remaining method in abstract class is concrete method. And the child class whose parent class is abstract is called concrete class.
# Every Abstract method has to be implemented by the child class after then child class will be able to inherit the parent class other properties and methods. 
# we can't make the objects of the abstract class.
# Abstraction means hiding the implementation details and showing only the essential features to the user.?
# abstraction forces consistency.
# ABC (Abstract Base Class) 
from abc import ABC, abstractmethod

# Create an abstract class
class Animal(ABC):
   
    @abstractmethod
    def make_sound(self):
        pass
   
    @abstractmethod
    def move(self):
        pass
   
    def sleep(self):
        print("Zzz... sleeping")
        return

# %%
# Create concrete classes that inherit from Animal
class Dog(Animal):
   
    def make_sound(self):
        print("Woof! Woof!")
   
    def move(self):
        print("Running on four legs")

   

class Bird(Animal):
   
    def make_sound(self):
        return f"Chirp! Chirp!"
   
    def move(self):
        print("Flying in the sky")

# %%
try:
    dog = Dog()
    dog.sleep()
    print("successfully instantiate the class Dog")
except TypeError as e:
    print(f"Error: {e}")
# Out:
# Zzz... sleeping
# successfully instantiate the class Dog

# %%
# Trying to instantiate the abstract class will raise an error
try:
    animal = Animal()
except TypeError as e:
    print(f"Error: {e}")
# Out:
# Error: Can't instantiate abstract class Animal without an implementation for abstract methods 'make_sound', 'move'

# %%
# Create instances of concrete classes
dog = Dog()
bird = Bird()

# Demonstrate abstraction in action
print("\nDog behaviors:")
dog.make_sound()
dog.move()
dog.sleep()

print("-" *10)
# Demonstrate abstraction in action
print("\n Bird behaviors:")
print(bird.make_sound())
bird.move()
bird.sleep()
# Out:
# Dog behaviors:
# Woof! Woof!
# Running on four legs
# Zzz... sleeping
# ----------
#
#  Bird behaviors:
# Chirp! Chirp!
# Flying in the sky
# Zzz... sleeping

# %% [raw]
# # ### Session Objectives:
# # *   Understand the concept of Polymorphism, particularly "Duck Typing" in Python.
# # *   See how polymorphism works with function parameters and in class hierarchies.
# # *   Learn about Magic Methods (Dunder Methods) and their purpose.
# # *   Implement common magic methods like `__str__` and `__len__`.
# # *   Get a brief introduction to Operator Overloading using magic methods (e.g., `__add__`).

# %% [markdown]
# **Today's Focus:** We'll explore two powerful OOP concepts:
#   1.  **Polymorphism:** How objects of different types can be treated uniformly if they share a common interface (like methods with the same name). The term means "many forms".
#   2.  **Magic Methods:** Special methods in Python (like `__init__`) that start and end with double underscores (`__`). They allow our custom objects to work with built-in Python operations (like `print()`, `len()`, `+`)

# %% [raw]
# # ## Polymorphism ()
#
#
# # **Concept:** Polymorphism allows us to perform a single action in different ways. In programming, it means we can often use objects
# # of different classes through the same interface (e.g., call the same method name on them).
#
#
#
# # **Python's Approach: Duck Typing**
# # Python uses a concept often called "Duck Typing". The name comes from the saying:
# # > "If it walks like a duck and it quacks like a duck, then it must be a duck."
# # Because of Duck Typing:
#
# You can pass a Dog, a Cat, or a Duck instance into make_it_speak().
#
# As long as that object has a .speak() method, Python will happily execute it. It doesn't care if they share a common parent class like Animal—it only cares that they can "quack" (have the .speak behavior).
#
#
# # This means Python often cares more about whether an object *can do* something (does it have the right methods/attributes?)
# # rather than what its *exact type* is. It doesn't require explicit interfaces or parent classes in all cases (though it works
# # well with them too).

# %%
# here every class has speak() function but each speak() function is defined in different way according to the class and now when objects of different classes call speak() speak function performs different function
# so one function has different role hence that function is showing polymorphism
class Dog:
    def speak(self):
        print("Woof!")

class Cat:
    def speak(self):
        print("Meow!")

class Duck:
    def speak(self):
        print("Quack!")

# Create instances
dog = Dog()
cat = Cat()
duck = Duck()

# %%
def make_it_speak(animal):
    try:
        animal.speak()
    except Exception as e:
        print(len(animal))
        print("This animal can't make sound.",e)

make_it_speak(dog)
make_it_speak(cat)
make_it_speak(duck)


# animal = [dog, cat, duck]
# for x in animal:
#     make_it_speak(x)
a = "hello"
make_it_speak(a)
# Out:
# Woof!
# Meow!
# Quack!
# 5
# This animal can't make sound. 'str' object has no attribute 'speak'

# %%
# ## Part 3: Magic Methods (Dunder Methods)
#
# **Concept:** Special methods that Python implicitly calls when you use certain syntax or built-in functions on your objects.
They are easily recognizable by the double underscores at the beginning and end of their names (e.g., `__init__`, `__str__`).
# They allow you to define how your custom objects behave like built-in types.

# %%
# ### Common Magic Method: `__str__(self)`
#
# *   **Purpose:** Returns a user-friendly string representation of the object.
# *   **Called By:** `print(obj)`, `str(obj)`, string formatting (like f-strings `{obj}`).
# *   **Return Value:** Must return a string.
#
# If you don't define `__str__`, Python uses a default representation (often showing the class name and memory address),
# which isn't very informative.

# %%
# here we are overwriting the dunder function str and obviously init as our own choice which automatically gets called when we do certain operations on the boject 
# __str__ has its own definition but we are modifying it as our choice and now when we print the object we get the output according to us 

class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        # This defines what print(book_object) will show
        return f"'{self.title}' by {self.author} ({self.pages} pages)"

# Create a book instance
book1 = Book("Python Crash Course", "Eric Matthes", 193)

# Print the book object
print("--- Printing book object (default) ---")
print(book1)
print(str(book1))
# Out:
# --- Printing book object (default) ---
# 'Python Crash Course' by Eric Matthes (193 pages)
# 'Python Crash Course' by Eric Matthes (193 pages)

# %%
# here we have done same thing with len dunder function
class Playlist:
    def __init__(self, name):
        self.name = name
        self._songs = []

    def add_song(self, title):
        self._songs.append(title)
        print(f"Added '{title}' to playlist '{self.name}'.")

    # Magic method to define the 'length' of a playlist
    def __len__(self):
       
        return len(self._songs)

    # Let's add __str__ too for better printing
    def __str__(self):
        song_list = "\n  - ".join(self._songs)
        if not song_list:
             return f"Playlist '{self.name}' (0 songs)"
        return f"Playlist '{self.name}' ({len(self)} songs):\n  - {song_list}"


# Create a playlist
my_playlist = Playlist("Chill Vibes")

# Check its length (initially 0)
print(f"Length of playlist: {len(my_playlist)}")
print(my_playlist)

# Add songs
my_playlist.add_song("Weightless ")
my_playlist.add_song("Teardrop ")
my_playlist.add_song("Yesterday")

# Check its length again
print(f"\nLength of playlist now: {len(my_playlist)}")


# Print the playlist using its __str__ method
print(my_playlist)
# Out:
# Length of playlist: 0
# Playlist 'Chill Vibes' (0 songs)
# Added 'Weightless ' to playlist 'Chill Vibes'.
# Added 'Teardrop ' to playlist 'Chill Vibes'.
# Added 'Yesterday' to playlist 'Chill Vibes'.
#
# Length of playlist now: 3
# Playlist 'Chill Vibes' (3 songs):
#   - Weightless
#   - Teardrop
#   - Yesterday

# %%
# ### Brief Intro to Operator Overloading
# Magic methods also allow you to define how standard operators (`+`, `-`, `*`, `/`, `==`, `<`, `>`, etc.) work with your custom objects.
# This is called **operator overloading**.

# Example: Using `__add__(self, other)` to overload the `+` operator.


class Vector2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

    # Overload the + operator for Vector2D objects
    def __add__(self, other):
        # Check if the 'other' object is also a Vector2D (good practice)
        if isinstance(other, Vector2D):
            # Return a *new* Vector2D object representing the sum
            new_x = self.x + other.x
            new_y = self.y + other.y
            return Vector2D(new_x, new_y)
        else:
            # Indicate that addition with this type is not supported
            return NotImplemented # Special value

    # Example: Overload == operator
    def __eq__(self, other):
        if isinstance(other, Vector2D):
            return self.x == other.x and self.y == other.y
        return False

# Create some vectors
v1 = Vector2D(1, 2)
v2 = Vector2D(3, 4)
v3 = Vector2D(4, 6)
v4 = Vector2D(1, 2)

print(f"v1 = {v1}")
print(f"v2 = {v2}")

# Use the overloaded + operator
v_sum = v1 + v2
print(f"v1 + v2 = {v_sum}")
print(f"Is v_sum a Vector2D? {isinstance(v_sum, Vector2D)}")

# Use the overloaded == operator
print(f"Does v1 == v2? {v1 == v2}")
print(f"Does v1 == v4? {v1 == v4}") # Should be True because of __eq__
print(f"Does v_sum == v3? {v_sum == v3}") # Should be True

# %%
# Other common operator magic methods include:
# `__sub__(self, other)` for `-`
# `__mul__(self, other)` for `*`
# `__lt__(self, other)` for `<`
# `__gt__(self, other)` for `>`
# `__eq__(self, other)` for `==`
# ...and many more!

# %%
# ## Part 4: Activity & Exercises
#
# **Activity: Enhance the `ShoppingCart`**
#
# 1.  Define a simple `Product` class:
#     *   It should have `name` (string) and `price` (float) attributes set in `__init__`.
#     *   Implement the `__str__` method to return a string like "Product Name: $Price" (e.g., "Laptop: $1200.50").
# 2.  Define a `ShoppingCart` class:
#     *   It should have an internal list (e.g., `self._items`) to store `Product` objects, initialized as empty in `__init__`.
#     *   Implement an `add_item(self, product)` method that adds a `Product` object to the internal list. Ensure it only adds `Product` objects (use `isinstance`).
#     *   Implement the `__len__(self)` method to return the number of *distinct products* in the cart.
#     *   Implement a `get_total_price(self)` method that calculates and returns the sum of the prices of all items in the cart.
#     *   Implement the `__str__(self)` method to return a multi-line string representing the cart. It should:
#         *   Start with something like "Shopping Cart ({number} items):". Use `__len__` here.
#         *   List each product on a new line (using the `Product`'s `__str__`). Indent the product lines slightly (e.g., with "  - ").
#         *   End with the total price, like "Total Price: $XXX.XX". Use `get_total_price`.
# 3.  Test your classes: Create a few `Product` objects, add them to a `ShoppingCart` instance, then print the cart and check its length.

# %%
class Product():
    def __init__(self, name, price):
        self.name = name 
        self.price = price
    def __str__(self):
        return f"{self.name} : ${self.price}"
class ShoppingCart():
    def __init__(self):
        
        self._items = []
    def add_item(self, product):
        if isinstance(product , Product):
            self._items.append(product)
    def __len__(self):
        return len(self._items)
    def get_total_price(self):
        total = 0
        for product in self._items:
            total += product.price
        return total
    def print_product(self):
        print(self._items)
    def __str__(self):
        cart = f"Shopping Cart ({len(self)} items) : \n"
        for product in self._items:
            cart += f" - {product}\n"
        cart += f"total price : ${self.get_total_price():.2f}"
        return cart
        
# ----------------------
# Testing the Classes
# ----------------------

p1 = Product("Laptop", 1200.50)
p2 = Product("Mouse", 25.99)
p3 = Product("Keyboard", 55.75)

cart = ShoppingCart()

cart.add_item(p1)
cart.add_item(p2)
cart.add_item(p3)

print(cart)
print("\nNumber of items:", len(cart))
# Out:
# Shopping Cart (3 items) :
#  - Laptop : $1200.5
#  - Mouse : $25.99
#  - Keyboard : $55.75
# total price : $1282.24
#
# Number of items: 3

# %%
# Import module 
# We use multiple files to write the code of the project so there is need of functions, variable etc used in one file in another file so that's why we use such import keyword to do that
