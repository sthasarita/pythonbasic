# %% [markdown]
# ### What are Dictionaries?
# Unordered collections of key-value pairs
#
# Keys must be unique and immutable (strings, numbers, tuples)
#
# Values can be any Python object

# %%
empty_dictionary = {}
print(empty_dictionary)
print(type(empty_dictionary))
# Out:
# {}
# <class 'dict'>

# %%
# method 1 : using {}
student = {
    "name":"Sarita",
    "age":20,
    "courses":['physics','math'],
    "gender": "female",
  
    
}
print(type(student))
print(student)
# Out:
# <class 'dict'>
# {'name': 'Sarita', 'age': 20, 'courses': ['physics', 'math'], 'gender': 'female'}

# %%
print(student['name'])
student['name']
# Out:
# Sarita
# 'Sarita'

# %%
student["address"] = "Kathmandu Nepal"
print(student)
student
# Out:
# {'name': 'Sarita', 'age': 20, 'courses': ['physics', 'math'], 'gender': 'male', 'address': 'Kathmandu Nepal'}
# {'name': 'Sarita',
#  'age': 20,
#  'courses': ['physics', 'math'],
#  'gender': 'male',
#  'address': 'Kathmandu Nepal'}

# %%
student["courses"][1]
# Out:
# 'math'

# %%
print(student["name"])
print(student.get('age'))
print(student.get('courses'))
# Out:
# Sarita
# 20
# ['physics', 'math']

# %%
print(student.get("name"))
student.get("id","Not found")
# Out:
# Sarita
# 'Not found'

# %%
# method 2 : using the dict() constructor
grades = dict([("Math", 90), ("Physics", 85)])
grades
# Out:
# {'Math': 90, 'Physics': 85}

# %%
employee = dict(
    name = "Bob",
    department = "HR",
    employee_id = 33646
)
print(employee)
# Out:
# {'name': 'Bob', 'department': 'HR', 'employee_id': 33646}

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
